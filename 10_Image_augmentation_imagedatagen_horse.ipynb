# %% [markdown]
# #  🖼️ Image Augmentation

# %% [markdown]
# ## Using Image data generator

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2025-05-31 14:06:04.895754: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-31 14:06:05.491619: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-31 14:06:05.498329: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-31 14:06:07.917006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
img = image.load_img('./data/horse.jpg', target_size=(224, 224))
x = image.img_to_array(img)

plt.imshow(img)  
plt.axis('off')  
plt.show()

# %%
x = x.reshape((1,) + x.shape)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
datagen = ImageDataGenerator(
    rotation_range=70,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
plt.figure(figsize=(10, 10))
i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.subplot(4, 2, i + 1)
    plt.imshow(image.array_to_img(batch[0]))
    plt.axis('off')
    i += 1
    if i == 8:
        break
plt.tight_layout()
plt.show()
