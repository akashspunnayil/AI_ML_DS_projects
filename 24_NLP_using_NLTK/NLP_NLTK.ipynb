# %% [markdown]
# # NLP (Natural Language Processing) - Using NLTK (Natural Language ToolKit)

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')        # for tokenization
nltk.download('stopwords')    # for stopwords removal
# Out:
# [nltk_data] Downloading package punkt_tab to /home/nerci/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /home/nerci/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
text = """Chess is a board game for two players. It is an abstract strategy game that involves no hidden information and no elements of chance. It is played on a square board consisting of 64 squares arranged in an 8×8 grid. The players, referred to as "White" and "Black", each control sixteen pieces: one king, one queen, two rooks, two bishops, two knights, and eight pawns, with each type of piece having a different pattern of movement. """

# %%
token = word_tokenize(text)

# %%
token
# Out:
# ['Chess',
#  'is',
#  'a',
#  'board',
#  'game',
#  'for',
#  'two',
#  'players',
#  '.',
#  'It',
#  'is',
#  'an',
#  'abstract',
#  'strategy',
#  'game',
#  'that',
#  'involves',
#  'no',
#  'hidden',
#  'information',
#  'and',
#  'no',
#  'elements',
#  'of',
#  'chance',
#  '.',
#  'It',
#  'is',
#  'played',
#  'on',
#  'a',
#  'square',
#  'board',
#  'consisting',
#  'of',
#  '64',
#  'squares',
#  'arranged',
#  'in',
#  'an',
#  '8×8',
#  'grid',
#  '.',
#  'The',
#  'players',
#  ',',
#  'referred',
#  'to',
#  'as',
#  '``',
#  'White',
#  "''",
#  'and',
#  '``',
#  'Black',
#  "''",
#  ',',
#  'each',
#  'control',
#  'sixteen',
#  'pieces',
#  ':',
#  'one',
#  'king',
#  ',',
#  'one',
#  'queen',
#  ',',
#  'two',
#  'rooks',
#  ',',
#  'two',
#  'bishops',
#  ',',
#  'two',
#  'knights',
#  ',',
#  'and',
#  'eight',
#  'pawns',
#  ',',
#  'with',
#  'each',
#  'type',
#  'of',
#  'piece',
#  'having',
#  'a',
#  'different',
#  'pattern',
#  'of',
# ...

# %%
stop_words = set(stopwords.words("english"))
filtered = [w for w in token if w.lower() not in stop_words]

# %%
filtered
# Out:
# ['Chess',
#  'board',
#  'game',
#  'two',
#  'players',
#  '.',
#  'abstract',
#  'strategy',
#  'game',
#  'involves',
#  'hidden',
#  'information',
#  'elements',
#  'chance',
#  '.',
#  'played',
#  'square',
#  'board',
#  'consisting',
#  '64',
#  'squares',
#  'arranged',
#  '8×8',
#  'grid',
#  '.',
#  'players',
#  ',',
#  'referred',
#  '``',
#  'White',
#  "''",
#  '``',
#  'Black',
#  "''",
#  ',',
#  'control',
#  'sixteen',
#  'pieces',
#  ':',
#  'one',
#  'king',
#  ',',
#  'one',
#  'queen',
#  ',',
#  'two',
#  'rooks',
#  ',',
#  'two',
#  'bishops',
#  ',',
#  'two',
#  'knights',
#  ',',
#  'eight',
#  'pawns',
#  ',',
#  'type',
#  'piece',
#  'different',
#  'pattern',
#  'movement',
#  '.']

# %%
stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered]

# %%
stemmed
# Out:
# ['chess',
#  'board',
#  'game',
#  'two',
#  'player',
#  '.',
#  'abstract',
#  'strategi',
#  'game',
#  'involv',
#  'hidden',
#  'inform',
#  'element',
#  'chanc',
#  '.',
#  'play',
#  'squar',
#  'board',
#  'consist',
#  '64',
#  'squar',
#  'arrang',
#  '8×8',
#  'grid',
#  '.',
#  'player',
#  ',',
#  'refer',
#  '``',
#  'white',
#  "''",
#  '``',
#  'black',
#  "''",
#  ',',
#  'control',
#  'sixteen',
#  'piec',
#  ':',
#  'one',
#  'king',
#  ',',
#  'one',
#  'queen',
#  ',',
#  'two',
#  'rook',
#  ',',
#  'two',
#  'bishop',
#  ',',
#  'two',
#  'knight',
#  ',',
#  'eight',
#  'pawn',
#  ',',
#  'type',
#  'piec',
#  'differ',
#  'pattern',
#  'movement',
#  '.']
